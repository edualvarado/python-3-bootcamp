# %%
from PIL import Image

# %%
mac = Image.open("example.jpg")

# %%
type(mac)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
mac.size
# Out:
# (1993, 1257)

# %%
mac.filename
# Out:
# 'example.jpg'

# %%
mac.format_description
# Out:
# 'JPEG (ISO 10918)'

# %%
mac.crop((0,0,100,100))
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x1DF37397BC8>

# %%
pencils = Image.open("pencils.jpg")

# %%
pencils
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1950x1300 at 0x1DF375282C8>

# %%
pencils.size
# Out:
# (1950, 1300)

# %%
x = 0
y = 0

w = 1950 / 3
h = 1300 / 10

pencils.crop((x,y,w,h))
# Out:
# <PIL.Image.Image image mode=RGB size=650x130 at 0x1DF373BDD88>

# %%
red = Image.open("red_color.jpg")

# %%
red
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200 at 0x18C84B16E88>

# %%
blue = Image.open("blue_color.PNG")

# %%
blue
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=200x200 at 0x18C84C89F08>

# %%
blue.putalpha(255)

# %%
blue
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Anaconda3\envs\tf-gpu-py37\lib\site-packages\PIL\PngImagePlugin.py in _save(im, fp, filename, chunk, save_all)
#    1171     try:
# -> 1172         rawmode, mode = _OUTMODES[mode]
#    1173     except KeyError as e:
#
# KeyError: 'PA'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# C:\Anaconda3\envs\tf-gpu-py37\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# C:\Anaconda3\envs\tf-gpu-py37\lib\site-packages\PIL\Image.py in _repr_png_(self)
#     670         """
#     671         b = io.BytesIO()
# --> 672         self.save(b, "PNG")
#     673         return b.getvalue()
#     674
#
# C:\Anaconda3\envs\tf-gpu-py37\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2156
#    2157         try:
# -> 2158             save_handler(self, fp, filename)
#    2159         finally:
#    2160             # do what we can to clean up
#
# C:\Anaconda3\envs\tf-gpu-py37\lib\site-packages\PIL\PngImagePlugin.py in _save(im, fp, filename, chunk, save_all)
#    1172         rawmode, mode = _OUTMODES[mode]
#    1173     except KeyError as e:
# -> 1174         raise OSError("cannot write mode %s as PNG" % mode) from e
#    1175
#    1176     #
#
# OSError: cannot write mode PA as PNG
# <PIL.PngImagePlugin.PngImageFile image mode=PA size=200x200 at 0x18C84C89F08>
